# %% [markdown]
# # Initial Fundus Image Preprocessing for U-Net Segmentation

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

from PIL import Image
from torchvision import transforms

# %%
papila_path = os.path.join("..", "data", "PAPILA", "FundusImages")
print(papila_path)
# Out:
# ../data/PAPILA/FundusImages

# %%
img_files = os.listdir(papila_path)
img1 = img_files[0]
img1
# Out:
# 'RET197OS.jpg'

# %% [markdown]
# ### Quick Visualization

# %%
img = mpimg.imread(os.path.join(papila_path, img1))
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
len(img_files)
# Out:
# 488

# %% [markdown]
# ### Transform Image to Tensor

# %%
input_image = Image.open(os.path.join(papila_path, img1))
m, s = np.mean(input_image, axis=(0, 1)), np.std(input_image, axis=(0, 1))
preprocess = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=m, std=s),
])
input_tensor = preprocess(input_image)
input_batch = input_tensor.unsqueeze(0)

# %%
input_tensor
# Out:
# tensor([[[-1.4712, -1.4712, -1.4712,  ..., -1.4712, -1.4712, -1.4712],
#          [-1.4712, -1.4712, -1.4712,  ..., -1.4712, -1.4712, -1.4712],
#          [-1.4712, -1.4712, -1.4712,  ..., -1.4712, -1.4712, -1.4712],
#          ...,
#          [-1.4712, -1.4712, -1.4712,  ..., -1.4712, -1.4712, -1.4712],
#          [-1.4712, -1.4712, -1.4712,  ..., -1.4712, -1.4712, -1.4712],
#          [-1.4712, -1.4712, -1.4712,  ..., -1.4712, -1.4712, -1.4712]],
#
#         [[-1.4678, -1.4678, -1.4678,  ..., -1.4678, -1.4678, -1.4678],
#          [-1.4678, -1.4678, -1.4678,  ..., -1.4678, -1.4678, -1.4678],
#          [-1.4678, -1.4678, -1.4678,  ..., -1.4678, -1.4678, -1.4678],
#          ...,
#          [-1.4678, -1.4678, -1.4678,  ..., -1.4678, -1.4678, -1.4678],
#          [-1.4678, -1.4678, -1.4678,  ..., -1.4678, -1.4678, -1.4678],
#          [-1.4678, -1.4678, -1.4678,  ..., -1.4678, -1.4678, -1.4678]],
#
#         [[-1.4408, -1.4408, -1.4408,  ..., -1.4408, -1.4408, -1.4408],
# ...

# %%
input_tensor.shape
# Out:
# torch.Size([3, 1934, 2576])

# %%
input_batch
# Out:
# tensor([[[[-1.4712, -1.4712, -1.4712,  ..., -1.4712, -1.4712, -1.4712],
#           [-1.4712, -1.4712, -1.4712,  ..., -1.4712, -1.4712, -1.4712],
#           [-1.4712, -1.4712, -1.4712,  ..., -1.4712, -1.4712, -1.4712],
#           ...,
#           [-1.4712, -1.4712, -1.4712,  ..., -1.4712, -1.4712, -1.4712],
#           [-1.4712, -1.4712, -1.4712,  ..., -1.4712, -1.4712, -1.4712],
#           [-1.4712, -1.4712, -1.4712,  ..., -1.4712, -1.4712, -1.4712]],
#
#          [[-1.4678, -1.4678, -1.4678,  ..., -1.4678, -1.4678, -1.4678],
#           [-1.4678, -1.4678, -1.4678,  ..., -1.4678, -1.4678, -1.4678],
#           [-1.4678, -1.4678, -1.4678,  ..., -1.4678, -1.4678, -1.4678],
#           ...,
#           [-1.4678, -1.4678, -1.4678,  ..., -1.4678, -1.4678, -1.4678],
#           [-1.4678, -1.4678, -1.4678,  ..., -1.4678, -1.4678, -1.4678],
#           [-1.4678, -1.4678, -1.4678,  ..., -1.4678, -1.4678, -1.4678]],
#
# ...

# %%
input_batch.shape
# Out:
# torch.Size([1, 3, 1934, 2576])
